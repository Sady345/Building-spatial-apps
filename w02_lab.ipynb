# %% [markdown]
# <a href="https://colab.research.google.com/github/Sady345/Building-spatial-apps/blob/main/w02_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Lab
#
# **Datasets**:
#
# The following datasets are used in this lab.
#
# - [nyc_subway_stations.tsv](https://open.gishub.org/data/duckdb/nyc_subway_stations.tsv)
# - [nyc_neighborhoods.tsv](https://open.gishub.org/data/duckdb/nyc_neighborhoods.tsv)

# %%
 # %pip install duckdb duckdb-engine jupysql
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.11/dist-packages (1.1.3)
# Requirement already satisfied: duckdb-engine in /usr/local/lib/python3.11/dist-packages (0.15.0)
# Requirement already satisfied: jupysql in /usr/local/lib/python3.11/dist-packages (0.10.17)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from duckdb-engine) (24.2)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.11/dist-packages (from duckdb-engine) (2.0.37)
# Requirement already satisfied: prettytable>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from jupysql) (3.12.0)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.11/dist-packages (from jupysql) (0.5.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from jupysql) (3.1.5)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.11/dist-packages (from jupysql) (25.1.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from jupysql) (0.2.26)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from ploomber-core>=0.2.7->jupysql) (6.0.2)
# Requirement already satisfied: posthog in /usr/local/lib/python3.11/dist-packages (from ploomber-core>=0.2.7->jupysql) (3.8.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable>=3.12.0->jupysql) (0.2.13)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->jupysql) (3.0.2)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.17.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.11/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2024.12.14)

# %%
import duckdb

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %% [markdown]
# ## Question 1: Creating Tables
#
# Create a database, then write a SQL query to create a table named `nyc_subway_stations` and load the data from the file `nyc_subway_stations.tsv` into it. Similarly, create a table named `nyc_neighborhoods` and load the data from the file `nyc_neighborhoods.tsv` into it.

# %%
# %sql duckdb:///:memory:
# %sql duckdb:///path/to/file.db ## % sql says all this code is sql

# %%
# %%sql
#
# INSTALL httpfs;
# LOAD httpfs;
#
# # installing the httpfs becuase that allows us to read csv and parquet files, hopefully it will also allow us to read tsv files
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# Creating a table for the subway stations
# %%sql

CREATE TABLE nyc_subway_stations AS SELECT * FROM 'https://open.gishub.org/data/duckdb/nyc_subway_stations.tsv';
# Out:
# RuntimeError: (duckdb.duckdb.CatalogException) Catalog Error: Table with name "nyc_subway_stations" already exists!
# [SQL: CREATE TABLE nyc_subway_stations AS SELECT * FROM 'https://open.gishub.org/data/duckdb/nyc_subway_stations.tsv';]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# Creating a table for the neighbourhoods

# %%sql
CREATE TABLE nyc_neigbourhoods AS SELECT * FROM 'https://open.gishub.org/data/duckdb/nyc_neighborhoods.tsv';
# Out:
# RuntimeError: (duckdb.duckdb.CatalogException) Catalog Error: Table with name "nyc_neigbourhoods" already exists!
# [SQL: CREATE TABLE nyc_neigbourhoods AS SELECT * FROM 'https://open.gishub.org/data/duckdb/nyc_neighborhoods.tsv';]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %%sql
#
# FROM nyc_neigbourhoods;
# Out:
#           BORONAME                      NAME
# 0         Brooklyn               Bensonhurst
# 1        Manhattan              East Village
# 2        Manhattan              West Village
# 3        The Bronx              Throggs Neck
# 4        The Bronx  Wakefield-Williamsbridge
# ..             ...                       ...
# 124       Brooklyn                  Red Hook
# 125         Queens   Douglastown-Little Neck
# 126         Queens                Whitestone
# 127         Queens                  Steinway
# 128  Staten Island                  Rosebank
#
# [129 rows x 2 columns]

# %%
# %%sql
#
# FROM nyc_subway_stations;
# Out:
#      OBJECTID     ID               NAME         ALT_NAME         CROSS_ST  \
# 0           1  376.0       Cortlandt St             None        Church St
# 1           2    2.0          Rector St             None             None
# 2           3    1.0        South Ferry             None             None
# 3           4  125.0           138th St  Grand Concourse  Grand Concourse
# 4           5  126.0           149th St  Grand Concourse  Grand Concourse
# ..        ...    ...                ...              ...              ...
# 486       487  909.0     JFK Terminal 8             None             None
# 487       488  903.0     Federal Circle       Rental Car             None
# 488       489  902.0  Long Term Parking             None             None
# 489       490  901.0       Howard Beach             None        159th Ave
# 490       491  900.0            Jamaica     Sutphin Blvd     Sutphin Blvd
#
#                                   LONG_NAME                             LABEL  \
# 0              Cortlandt St (R,W) Manhattan                Cortlandt St (R,W)
# 1                   Rector St (1) Manhattan                     Rector St (1)
# 2                 South Ferry (1) Manhattan                   South Ferry (1)
# 3    138th St / Grand Concourse (4,5) Bronx  138th St / Grand Concourse (4,5)
# 4      149th St / Grand Concourse (4) Bronx    149th St / Grand Concourse (4)
# ..                                      ...                               ...
# 486                  JFK Terminal 8, Queens                    JFK Terminal 8
# 487     Federal Circle / Rental Car, Queens       Federal Circle / Rental Car
# 488               Long Term Parking, Queens                 Long Term Parking
# 489                    Howard Beach, Queens                      Howard Beach
# 490          Jamaica / Sutphin Blvd, Queens            Jamaica / Sutphin Blvd
#
#        BOROUGH NGHBHD ROUTES TRANSFERS     COLOR  EXPRESS CLOSED
# 0    Manhattan   None    R,W       R,W    YELLOW     None    NaN
# 1    Manhattan   None      1         1       RED     None    NaN
# 2    Manhattan   None      1         1       RED     None    NaN
# 3        Bronx   None    4,5       4,5     GREEN     None    NaN
# 4        Bronx   None      4     2,4,5     GREEN  express    NaN
# ..         ...    ...    ...       ...       ...      ...    ...
# 486     Queens   None   None      None  AIR-BLUE     None    NaN
# 487     Queens   None   None      None  AIR-BLUE     None    NaN
# 488     Queens   None   None      None  AIR-BLUE     None    NaN
# 489     Queens   None   None         A  AIR-BLUE     None    NaN
# 490     Queens   None   None     E,J,Z  AIR-BLUE     None    NaN
#
# [491 rows x 14 columns]

# %% [markdown]
# ## Question 2: Column Filtering
#
# Write a SQL query to display the `ID`, `NAME`, and `BOROUGH` of each subway station in the `nyc_subway_stations` dataset.

# %%
# %%sql
# SELECT ID, NAME, BOROUGH
# FROM nyc_subway_stations
# Out:
#         ID               NAME    BOROUGH
# 0    376.0       Cortlandt St  Manhattan
# 1      2.0          Rector St  Manhattan
# 2      1.0        South Ferry  Manhattan
# 3    125.0           138th St      Bronx
# 4    126.0           149th St      Bronx
# ..     ...                ...        ...
# 486  909.0     JFK Terminal 8     Queens
# 487  903.0     Federal Circle     Queens
# 488  902.0  Long Term Parking     Queens
# 489  901.0       Howard Beach     Queens
# 490  900.0            Jamaica     Queens
#
# [491 rows x 3 columns]

# %% [markdown]
# ## Question 3: Row Filtering
#
# Write a SQL query to find all subway stations in the `nyc_subway_stations` dataset that are located in the borough of Manhattan.

# %%
# %%sql
# SELECT NAME, BOROUGH
# FROM nyc_subway_stations
# WHERE BOROUGH = 'Manhattan'
# Out:
#                    NAME    BOROUGH
# 0          Cortlandt St  Manhattan
# 1             Rector St  Manhattan
# 2           South Ferry  Manhattan
# 3              W 4th St  Manhattan
# 4              103rd St  Manhattan
# ..                  ...        ...
# 135             Wall St  Manhattan
# 136        Whitehall St  Manhattan
# 137        Cortlandt St  Manhattan
# 138  World Trade Center  Manhattan
# 139            Times Sq  Manhattan
#
# [140 rows x 2 columns]

# %% [markdown]
# ## Question 4: Sorting Results
#
# Write a SQL query to list the subway stations in the `nyc_subway_stations` dataset in alphabetical order by their names.

# %%
# %%sql
#
# SELECT NAME FROM nyc_subway_stations ORDER BY NAME ASC
# Out:
#                    NAME
# 0              103rd St
# 1              103rd St
# 2              103rd St
# 3              103rd St
# 4              104th St
# ..                  ...
# 486            Woodlawn
# 487  World Trade Center
# 488         Wyckoff Ave
# 489             York St
# 490          Zerega Ave
#
# [491 rows x 1 columns]

# %% [markdown]
# ## Question 5: Unique Values
#
# Write a SQL query to find the distinct boroughs represented in the `nyc_subway_stations` dataset.

# %%
# %%sql
#
# SELECT DISTINCT BOROUGH FROM nyc_subway_stations
# Out:
#          BOROUGH
# 0       Brooklyn
# 1         Queens
# 2      Manhattan
# 3          Bronx
# 4  Staten Island

# %% [markdown]
# ## Question 6: Counting Rows
#
# Write a SQL query to count the number of subway stations in each borough in the `nyc_subway_stations` dataset.

# %%
# %%sql
#
# SELECT BOROUGH, COUNT(*) AS station_count
# FROM nyc_subway_stations
# GROUP BY BOROUGH;
# Out:
#          BOROUGH  station_count
# 0      Manhattan            140
# 1          Bronx             69
# 2  Staten Island             22
# 3       Brooklyn            170
# 4         Queens             90

# %% [markdown]
# ## Question 7: Aggregating Data
#
# Write a SQL query to list the number of subway stations in each borough, sorted in descending order by the count.

# %%
# %%sql
#
# SELECT BOROUGH, COUNT(*) AS station_count
# FROM nyc_subway_stations
# GROUP BY BOROUGH ORDER BY station_count DESC;
# Out:
#          BOROUGH  station_count
# 0       Brooklyn            170
# 1      Manhattan            140
# 2         Queens             90
# 3          Bronx             69
# 4  Staten Island             22

# %% [markdown]
# ## Question 8: Joining Tables
#
# Write a SQL query to join the `nyc_subway_stations` and `nyc_neighborhoods` datasets on the borough name, displaying the subway station name and the neighborhood name.

# %%
# %%sql
#
# SELECT stations.NAME AS Station_name, neigbourhood.NAME AS Neighbourhood_name FROM nyc_subway_stations AS stations INNER JOIN nyc_neigbourhoods AS neigbourhood ON neigbourhood.BORONAME = stations.BOROUGH;
# Out:
#             Station_name Neighbourhood_name
# 0           Cortlandt St          Chinatown
# 1              Rector St          Chinatown
# 2            South Ferry          Chinatown
# 3               W 4th St          Chinatown
# 4                15th St           Red Hook
# ...                  ...                ...
# 11053     JFK Terminal 8         Auburndale
# 11054     Federal Circle         Auburndale
# 11055  Long Term Parking         Auburndale
# 11056       Howard Beach         Auburndale
# 11057            Jamaica         Auburndale
#
# [11058 rows x 2 columns]

# %% [markdown]
# ## Question 9: String Manipulation
#
# Write a SQL query to display the names of subway stations in the `nyc_subway_stations` dataset that contain the word "St" in their names.

# %%
# %%sql
# SELECT *
# FROM nyc_subway_stations
# WHERE NAME LIKE '% St%'
# Out:
#      OBJECTID     ID           NAME         ALT_NAME          CROSS_ST  \
# 0           1  376.0   Cortlandt St             None         Church St
# 1           2    2.0      Rector St             None              None
# 2           4  125.0       138th St  Grand Concourse   Grand Concourse
# 3           5  126.0       149th St  Grand Concourse   Grand Concourse
# 4           6   45.0       149th St  Grand Concourse   Grand Concourse
# ..        ...    ...            ...              ...               ...
# 222       420  245.0  Beach 67th St             None  Rockaway Freeway
# 223       421  251.0  Beach 90th St             None  Rockaway Freeway
# 224       422  252.0  Beach 98th St             None  Rockaway Freeway
# 225       438  177.0        Main St         Flushing     Roosevelt Ave
# 226       448  261.0    Steinway St             None          Broadway
#
#                                   LONG_NAME                             LABEL  \
# 0              Cortlandt St (R,W) Manhattan                Cortlandt St (R,W)
# 1                   Rector St (1) Manhattan                     Rector St (1)
# 2    138th St / Grand Concourse (4,5) Bronx  138th St / Grand Concourse (4,5)
# 3      149th St / Grand Concourse (4) Bronx    149th St / Grand Concourse (4)
# 4    149th St / Grand Concourse (2,5) Bronx  149th St / Grand Concourse (2,5)
# ..                                      ...                               ...
# 222                Beach 67th St (A) Queens                 Beach 67th St (A)
# 223              Beach 90th St (A,S) Queens               Beach 90th St (A,S)
# 224              Beach 98th St (A,S) Queens               Beach 98th St (A,S)
# 225           Main St / Flushing (7) Queens            Main St / Flushing (7)
# 226              Steinway St (G,R,V) Queens               Steinway St (G,R,V)
#
#        BOROUGH NGHBHD ROUTES TRANSFERS      COLOR  EXPRESS CLOSED
# 0    Manhattan   None    R,W       R,W     YELLOW     None    NaN
# 1    Manhattan   None      1         1        RED     None    NaN
# 2        Bronx   None    4,5       4,5      GREEN     None    NaN
# 3        Bronx   None      4     2,4,5      GREEN  express    NaN
# 4        Bronx   None    2,5     2,4,5  RED-GREEN  express    NaN
# ..         ...    ...    ...       ...        ...      ...    ...
# 222     Queens   None      A         A       BLUE     None    NaN
# 223     Queens   None    A,S       A,S       BLUE     None    NaN
# 224     Queens   None    A,S       A,S       BLUE     None    NaN
# 225     Queens   None      7         7     PURPLE  express    NaN
# 226     Queens   None  G,R,V     G,R,V      MULTI     None    NaN
#
# [227 rows x 14 columns]

# %% [markdown]
# ## Question 10: Filtering with Multiple Conditions
#
# Write a SQL query to find all subway stations in the `nyc_subway_stations` dataset that are in the borough of Brooklyn and have routes that include the letter "R".

# %%
# %%sql
# SELECT *
# FROM nyc_subway_stations
# WHERE BOROUGH = 'Brooklyn' AND ROUTES LIKE '%R%'
# Out:
#     OBJECTID     ID           NAME                   ALT_NAME       CROSS_ST  \
# 0         81  406.0        25th St                       None        4th Ave
# 1         82  407.0        36th St                       None        4th Ave
# 2         83  408.0        45th St                       None        4th Ave
# 3         86  409.0        53rd St                       None        4th Ave
# 4         88  410.0        59th St                       None        4th Ave
# 5         91  412.0        77th St                       None        4th Ave
# 6         96  413.0        86th St                       None        4th Ave
# 7         98  414.0        95th St                  Bay Ridge        4th Ave
# 8        100  404.0         9th St                    4th Ave        4th Ave
# 9        119  411.0  Bay Ridge Ave                       None        4th Ave
# 10       146  379.0       Court St               Borough Hall    Montague St
# 11       150  382.0     DeKalb Ave                       None   Flatbush Ave
# 12       188  380.0    Lawrence St                  MetroTech  Willoughby St
# 13       213  402.0     Pacific St  Brooklyn Academy of Music        4th Ave
# 14       218  405.0   Prospect Ave                       None        4th Ave
# 15       231  403.0       Union St                       None        4th Ave
#
#                                             LONG_NAME  \
# 0                              25th St (M,R) Brooklyn
# 1                          36th St (D,M,N,R) Brooklyn
# 2                                45th St (R) Brooklyn
# 3                                53rd St (R) Brooklyn
# 4                              59th St (N,R) Brooklyn
# 5                                77th St (R) Brooklyn
# 6                                86th St (R) Brooklyn
# 7                    95th St / Bay Ridge (R) Brooklyn
# 8                     9th St / 4th Ave (M,R) Brooklyn
# 9                          Bay Ridge Ave (R) Brooklyn
# 10             Court St / Borough Hall (M,R) Brooklyn
# 11                      DeKalb Ave (B,M,Q,R) Brooklyn
# 12             Lawrence St / MetroTech (M,R) Brooklyn
# 13  Pacific St / Brooklyn Academy of Music (D,M,N,...
# 14                        Prospect Ave (M,R) Brooklyn
# 15                            Union St (M,R) Brooklyn
#
#                                                LABEL   BOROUGH NGHBHD  \
# 0                                      25th St (M,R)  Brooklyn   None
# 1                                  36th St (D,M,N,R)  Brooklyn   None
# 2                                        45th St (R)  Brooklyn   None
# 3                                        53rd St (R)  Brooklyn   None
# 4                                      59th St (N,R)  Brooklyn   None
# 5                                        77th St (R)  Brooklyn   None
# 6                                        86th St (R)  Brooklyn   None
# 7                            95th St / Bay Ridge (R)  Brooklyn   None
# 8                             9th St / 4th Ave (M,R)  Brooklyn   None
# 9                                  Bay Ridge Ave (R)  Brooklyn   None
# 10                     Court St / Borough Hall (M,R)  Brooklyn   None
# 11                              DeKalb Ave (B,M,Q,R)  Brooklyn   None
# 12                     Lawrence St / MetroTech (M,R)  Brooklyn   None
# 13  Pacific St / Brooklyn Academy of Music (D,M,N,R)  Brooklyn   None
# 14                                Prospect Ave (M,R)  Brooklyn   None
# 15                                    Union St (M,R)  Brooklyn   None
#
#      ROUTES            TRANSFERS                COLOR  EXPRESS CLOSED
# 0       M,R                  M,R         BROWN-YELLOW     None    NaN
# 1   D,M,N,R              D,M,N,R  BROWN-ORANGE-YELLOW  express    NaN
# 2         R                    R               YELLOW     None    NaN
# 3         R                    R               YELLOW     None    NaN
# 4       N,R                  N,R               YELLOW  express    NaN
# 5         R                    R               YELLOW     None    NaN
# 6         R                    R               YELLOW     None    NaN
# 7         R                    R               YELLOW     None    NaN
# 8       M,R                F,M,R         BROWN-YELLOW     None    NaN
# 9         R                    R               YELLOW     None    NaN
# 10      M,R          M,R,2,3,4,5         BROWN-YELLOW     None    NaN
# 11  B,M,Q,R              B,M,Q,R                MULTI  express    NaN
# 12      M,R                  M,R         BROWN-YELLOW     None    NaN
# 13  D,M,N,R  B,D,M,N,Q,R,2,3,4,5  BROWN-ORANGE-YELLOW  express    NaN
# 14      M,R                  M,R         BROWN-YELLOW     None    NaN
# 15      M,R                  M,R         BROWN-YELLOW     None    NaN

# %% [markdown]
# Once you've completed your attempt, you can check your answers [here](https://github.com/oballinger/CASA0025/blob/main/notebooks/W02_lab_solution.ipynb).
